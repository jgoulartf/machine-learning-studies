# %% [markdown]
# #Exercício: Pré-Processanento

# %% [markdown]
# ## Analise o dataset Iris e realize as tarefas de pré-processamento que achar necessárias. Apresente a sua análise exploratória nos dados, justificando a necessidade (ou não necessidade) da aplicação de cada uma das tarefas estudadas em sala de aula.

# %%
#monte o drive caso precise usar/salvar arquivos do seu drive
from google.colab import drive
drive.mount('/content/drive')
#mude o ponto de execução para outro diretório, caso deseje
# %cd /content/drive/MyDrive/Colab Notebooks/AprendizadoMaquina
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/AprendizadoMaquina'
# /content

# %% [markdown]
# ## Importe todas as bibliotecas que for utilizar

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Faça o download do DATASET IRIS. Disponível na própria bilioteca sklearn

# %%
#Baixando o dataset iris da biblioteca sklearn
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()

# %%
# Montando o Dataframe
df = pd.DataFrame(iris["data"], columns=iris["feature_names"])
df.loc[:,  "class"] = iris["target"]
df["class"].value_counts().round()
# Out:
# 0    50
# 1    50
# 2    50
# Name: class, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop(columns=['class']), df['class'], test_size = 0.33)
print(x_test.count())
# Out:
# sepal length (cm)    50
# sepal width (cm)     50
# petal length (cm)    50
# petal width (cm)     50
# dtype: int64

# %%
df["class"].value_counts().round()
# Out:
# 0    50
# 1    50
# 2    50
# Name: class, dtype: int64

# %% [markdown]
# ## Realize as tarefas de Pré-processamento que julgar necessárias. Justifique suas escolhas por meio de análise exploratórias nos dados.

# %% [markdown]
# ### Os dados necessitam de tratamento de dados faltosos?
# - Não, pois como vemos abaixo usando o metodo info() do pandas, o dataset está inteiramente preenchido com valores não nulos.

# %%
# Verificando dados faltosos.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   class              150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %% [markdown]
# ### Os dados necessitam de tratamento de outliers? Se sim, em quais atributos?
# - Sim, como analisado abaixo, os dados precisam de tratamento de outliers no atributo sepal width (cm).

# %%
# Analisando outliers.
df.plot(kind = "box") 

# Vemos que tem outliers na segunda coluna, sepal width (cm)

# %%
# Analisando outliers.
fig, f1_axes = plt.subplots(ncols = 2, nrows = 2, figsize = (15, 10))
fig.suptitle("Gráficos", size = 20)

f1_axes[0, 0].boxplot(df) # matplotlib ver doc
f1_axes[0, 0].set_title("Boxplot Todos os dados");

f1_axes[0, 1].boxplot(df["sepal width (cm)"])
f1_axes[0, 1].set_title("Sepal width (cm) boxplot")
# 

fig.show()

# %% [markdown]
# ### É necessário realizar transformação nos tipos de dados (Categóricos /Numéricos)

# %%
#

# %% [markdown]
# ### Devemos realizar normalização nos dados ?

# %%
#

# %% [markdown]
# ### Existe correlação nos dados. É recomendável uma redução na dimensionalidade dos dados?

# %%
#

# %% [markdown]
# ### Existe desbalanceamento nos dados?
